# %% [markdown]
# <a href="https://colab.research.google.com/github/Domo7533/GCP-Practice-Project/blob/master/Copy_of_acme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
medical_df = pd.read_csv('insurance.csv')

# %%
# prompt: medical_df

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# This is already present in the provided code
medical_df = pd.read_csv('insurance.csv')

# Assuming you want to do something with the dataframe
# Example: print the first 5 rows
print(medical_df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print (medical_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None

# %%
medical_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
  import plotly.express as px
  import seaborn as sns
  import matplotlib.pyplot as plt
  import matplotlib
  import numpy as np
  import pandas as pd
  # %matplotlib inline
  sns.pairplot(medical_df)

# %%
sns.set_style ('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
medical_df.age.describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
fig = px.histogram(medical_df, x="age", nbins=47, marginal ='box', title ='Distribution of Age',)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
medical_df.charges.describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
fig = px.histogram(medical_df, x="bmi", color_discrete_sequence = ['red'], marginal ='box', title ='Distribution of BMI (Body Mass Index)',)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
  pd.read_csv('insurance.csv')
  medical_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
fig = px.histogram(medical_df, x='charges', color ='age', color_discrete_sequence =['green', 'grey'], marginal ='box', title ='Annual Medical Charges',)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(medical_df, x='charges', color ='bmi', color_discrete_sequence =['green', 'grey'], marginal ='box', title ='Annual Medical Charges',)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(medical_df, x='charges', color ='region', color_discrete_sequence =['Green', 'grey'], marginal ='box', title ='Annual Medical Charges',)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-7ed6a8059e69> in <cell line: 0>()
# ----> 1 fig = px.histogram(medical_df, x='charges', color ='region', color_discrete_sequence =['Green', 'grey'], marginal ='box', title ='Annual Medical Charges',)
#       2 fig.update_layout(bargap=0.1)
#       3 fig.show()
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
# ...

# %%
medical_df.smoker.value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
px.histogram(medical_df, x='smoker', color ='sex', title ='smoker',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
  medical_df.sex.describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
px.histogram(medical_df, x='sex', color ='smoker', title ='sex',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
medical_df.region.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-011d85ad4b92> in <cell line: 0>()
# ----> 1 medical_df.region.describe()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'region'

# %%
px.histogram(medical_df, x='region', color ='smoker', title ='region',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9d8f094e69ec> in <cell line: 0>()
# ----> 1 px.histogram(medical_df, x='region', color ='smoker', title ='region',)
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     478     `orientation` is `'h'`).
#     479     """
# --> 480     return make_figure(
#     481         args=locals(),
#     482         constructor=go.Histogram,
# ...

# %%
px.histogram(medical_df, x='children', color ='smoker', title ='region',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-a011018db6f0> in <cell line: 0>()
# ----> 1 px.histogram(medical_df, x='children', color ='smoker', title ='region',)
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     478     `orientation` is `'h'`).
#     479     """
# --> 480     return make_figure(
#     481         args=locals(),
# ...

# %%
  fig =px.scatter(medical_df, x='age', y= 'charges',color ='smoker', opacity =0.8, hover_data =['sex'], title ='Age vs Charges',)
  fig.update_traces(marker_size=5)
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig =px.scatter(medical_df, x='bmi', y= 'charges',color ='smoker', opacity =0.8, hover_data =['sex'], title ='BMI vs Charges',)
fig.update_traces(marker_size=5)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c62c93d77393> in <cell line: 0>()
# ----> 1 fig =px.scatter(medical_df, x='bmi', y= 'charges',color ='smoker', opacity =0.8, hover_data =['sex'], title ='BMI vs Charges',)
#       2 fig.update_traces(marker_size=5)
#       3 fig.show()
#
# ...

# %%
medical_df=pd.read_csv('insurance.csv')
print(medical_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None

# %%
smoker_values = {'no': 0, 'yes': 1}
smoker_numeric = medical_df.smoker.map(smoker_values)
medical_df.charges.corr(smoker_numeric )
# Out:
# 0.787251430498478

# %%
medical_df.charges.corr(medical_df.children)
# Out:
# 0.06799822684790478

# %%
sex_values = {'male': 0, 'female': 1}
sex_numeric = medical_df.sex.map(sex_values)
medical_df.charges.corr(sex_numeric)
# Out:
# -0.057292062202025484

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming medical_df is already loaded

# Convert categorical columns to numerical using one-hot encoding
medical_df = pd.get_dummies(medical_df, columns=['sex', 'smoker', 'region'], drop_first=True)
# drop_first=True to avoid multicollinearity

# Calculate the correlation matrix
corr_matrix = medical_df.corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='Reds')
plt.title('Correlation Matrix')
plt.show()

# %%
medical_df=pd.read_csv('insurance.csv')
non_smoker_df = medical_df[medical_df.smoker =='no']
plt.title('age vs. charges')
sns.scatterplot(data=non_smoker_df, x='age', y='charges', alpha=0.7, s=15)
# Out:
# <Axes: title={'center': 'age vs. charges'}, xlabel='age', ylabel='charges'>

# %%
  def estimate_charges(age, w, b):
    return w * age + b

# %%
w = 50
b = 100
ages = non_smoker_df.age
estimated_charges = estimate_charges(ages, w, b)
plt.plot(ages, estimated_charges, 'r-o');
plt.xlabel('Age');
plt.ylabel('Estimated Charges');
plt.show()

# %%
ages = non_smoker_df.age
ages
# Out:
# 1       18
# 2       28
# 3       33
# 4       32
# 5       31
#         ..
# 1332    52
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# Name: age, Length: 1064, dtype: int64

# %%
target =non_smoker_df.charges
target
plt.plot(ages, estimated_charges,'r', alpha=0.9);
plt.scatter(ages, target, s=8, alpha=0.8);
plt.xlabel('Age');
plt.ylabel('Charges')
plt.legend(['Estimated', 'Actual']);
plt.show()

# %%
def try_parameters(w, b):
    ages = non_smoker_df.age
    target =non_smoker_df.charges
    estimated_charges = estimate_charges(ages, w, b)
    plt.plot(ages, estimated_charges, 'r', alpha=0.9);
    plt.scatter(ages, target, s=8, alpha=0.8);
    plt.xlabel('Age');
    plt.ylabel('Charges')
    plt.legend(['Estimated', 'Actual']);

# %%
try_parameters(220, -1340)
plt.show()

# %%
targets = non_smoker_df.charges
targets
# Out:
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1064, dtype: float64

# %%
predictions = estimated_charges
predictions
# Out:
# 1       1000
# 2       1500
# 3       1750
# 4       1700
# 5       1650
#         ...
# 1332    2700
# 1333    2600
# 1334    1000
# 1335    1000
# 1336    1150
# Name: age, Length: 1064, dtype: int64

# %%
import numpy as np
def rmse(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

# %%
w = 50
b = 100

# %%
try_parameters(w, b)
plt.show()
targets = non_smoker_df.charges
predicted = estimate_charges(non_smoker_df.age, w, b)
print(rmse(targets, predictions))
# Out:
# 8461.949562575493

# %%
rmse(targets, predictions)
# Out:
# 8461.949562575493

# %%
def try_parameters(w, b):
    ages = non_smoker_df.age
    target =non_smoker_df.charges
    predictions = estimate_charges(ages, w, b)
    plt.plot(ages, predicted, 'r', alpha=0.9);
    plt.scatter(ages, target, s=8, alpha=0.8);
    plt.xlabel('Age');
    plt.ylabel('Charges')
    plt.legend(['Prediction', 'Actual']);
    loss = rmse(target, predictions)
    print("RMSE Loss: ", loss)

# %%
try_parameters(400, 5550)
plt.show()
# Out:
# RMSE Loss:  13815.372300701603

# %%
pip install scikit-Learn --quiet

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
help(model.fit)
# Out:
# Help on method fit in module sklearn.linear_model._base:
#
# fit(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Fit linear model.
#
#     Parameters
#     ----------
#     X : {array-like, sparse matrix} of shape (n_samples, n_features)
#         Training data.
#
#     y : array-like of shape (n_samples,) or (n_samples, n_targets)
#         Target values. Will be cast to X's dtype if necessary.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Individual weights for each sample.
#
#         .. versionadded:: 0.17
#            parameter *sample_weight* support to LinearRegression.
#
#     Returns
#     -------
#     self : object
#         Fitted Estimator.

# %%
inputs.shape
# Out:
# (1064, 1)

# %%
inputs =non_smoker_df[['age']]
targtets = non_smoker_df.charges
print('inputs.shape :', inputs.shape)
print('targets.shape :', targtets.shape)
# Out:
# inputs.shape : (1064, 1)
# targets.shape : (1064,)

# %%
model.fit(inputs, targtets)
# Out:
# LinearRegression()

# %%
model.predict(np.array([[23],
                       [37],
                       [61]]))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([ 4055.30443855,  7796.78921819, 14210.76312614])

# %%
predictions =model.predict(inputs)
predictions
# Out:
# array([2719.0598744 , 5391.54900271, 6727.79356686, ..., 2719.0598744 ,
#        2719.0598744 , 3520.80661289])

# %%
 rmse(targtets, predictions)
# Out:
# 4662.505766636395

# %%
model.coef_
# Out:
# array([267.24891283])

# %%
model.intercept_
# Out:
# -2091.4205565650864
